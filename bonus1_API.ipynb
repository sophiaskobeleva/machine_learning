# %% [markdown]
# # Программирование на Python
#
# # Бонусное задание. Работа с API YouTube.

# %% [markdown]
# **1. Подгрузите необходимые модули, своими словами поясните, зачем они нужны. Обратитесь к API YouTube, используя свой API key.**

# %% [markdown]
# Импортируем модуль **googleapiclient.discovery**, который позволит нам использовать API YouTube и обратимся к API YouTube, используя наш ключ. Позже мы импорируем модуль **pandas**, который поможет нам создать таблицу с полученными данными.

# %%
# !pip install google-api-python-client
import googleapiclient.discovery as api

key = 'AIzaSyAFdms5tMYjx0DFieY2pA3YDvLAbx-cDzg'
youtube = api.build('youtube', 'v3', developerKey = key)

# %% [markdown]
# **2. Создайте поисковый запрос с помощью метода `.search()` по интересующей вас теме с параметром `maxResults = 50`**
# **3. Добавьте в запрос параметр `order` (значение укажите параметра сами, любое из [документации](https://developers.google.com/youtube/v3/docs?hl=ru) по этому API).**

# %%
request_search = youtube.search().list(
    part = "snippet",
    maxResults = 50,
    q = "проект загородного дома",
    type = 'video',
    order = 'rating')

response_search = request_search.execute()
response_search
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '-Gxv-sFWvrXc_-EKzvSGILLQuG0',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'RU',
#  'pageInfo': {'totalResults': 320217, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'YQQxbM9BGr5kJpaFY0G-aCBn11g',
#    'id': {'kind': 'youtube#video', 'videoId': 'm6ts866JgYc'},
#    'snippet': {'publishedAt': '2017-04-28T10:30:14Z',
#     'channelId': 'UCAddONSeww-GBynzG-oA1ag',
#     'title': 'Отрывок 3 из 5-го этапа обучения &quot;Рабочий проект загородного дома&quot;',
#     'description': 'Подробнее по ссылке: http://xn--e1agdcsfheqm.xn--p1ai/rabochiy-proekt-dlya-stroitelstva-doma.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/m6ts866JgYc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/m6ts866JgYc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...

# %% [markdown]
# **4. Создайте таблицу по всем видео, которые были выгружены на данный момент.**

# %%
import pandas as pd
table = pd.json_normalize(response_search['items'])
table
# Out:
#                     kind                         etag        id.kind  \
# 0   youtube#searchResult  YQQxbM9BGr5kJpaFY0G-aCBn11g  youtube#video
# 1   youtube#searchResult  j-VFa0NUt9kO0ZI0xTLn9x4wpOk  youtube#video
# 2   youtube#searchResult  F4JgoM-7y0mhqDWAyC0oy9Qdov0  youtube#video
# 3   youtube#searchResult  TJpAShnJxNVNBwUKoXihNPBOx04  youtube#video
# 4   youtube#searchResult  nZg4blnM02sqM4tXMbKq4LRRDOY  youtube#video
# 5   youtube#searchResult  zT3rU71o3pwseOrOU3EGmUynWJw  youtube#video
# 6   youtube#searchResult  -hcIdjqXtpDZWjvyocULgPJjRGU  youtube#video
# 7   youtube#searchResult  oPs4U23Dy4V3SEcVxe8cVaAZ3og  youtube#video
# 8   youtube#searchResult  djNnCxw6HRZbSfgp8CbMqiUPij0  youtube#video
# 9   youtube#searchResult  mft9V7LCQSII71f135FHcB3dZDs  youtube#video
# 10  youtube#searchResult  nVRHvKDVx5uO2u5pEvHzjBYU6os  youtube#video
# 11  youtube#searchResult  pKNYdQkLv3ZuJFwRfLcWQipakVI  youtube#video
# 12  youtube#searchResult  MOyY10T9CiPnqE2Sa4Gl9dHEnmE  youtube#video
# ...

# %% [markdown]
# **5. Обратите внимание на `nextPageToken`. Запустите цикл, который будет работать, *пока* `nextPageToken` есть в выдаче и количество его итераций не превысило десять.**
#
# **На каждой итерации цикла должно происходить:**
# + создание нового запроса (пусть в него добавляется аругумент `pageToken`, также почитайте о нем в документации)
# + создание новой таблицы (очевидно, из новых, полученных пунктом выше, данных)
# + объединение новой таблицы и той, что была до нее (здесь обратите внимание на [документацию](https://pandas.pydata.org/docs/user_guide/merging.html) модуля pandas и работу метода `.concat()`)
#
# **Посмотрите на количество видео в ваших данных, а затем [уберите из таблицы дубликаты](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html?highlight=drop_duplicates#pandas.DataFrame.drop_duplicates) по столбцу `id.videoId`.**

# %%
pages = 0
next_page = None
table = None
while pages < 10:
    new_request = youtube.search().list(
        part = "snippet",
        maxResults = 50,
        q = "проект загородного дома",
        type = 'video',
        order = 'rating',
        pageToken = next_page)
    
    new_response = new_request.execute()
    table_new = pd.json_normalize(new_response['items'])
    
    if table is None:
        table = table_new
    else:
        table = pd.concat([table, table_new])
        next_page = new_response['nextPageToken']
        pages += 1

# %%
table
# Out:
#                     kind                         etag        id.kind  \
# 0   youtube#searchResult  YQQxbM9BGr5kJpaFY0G-aCBn11g  youtube#video
# 1   youtube#searchResult  j-VFa0NUt9kO0ZI0xTLn9x4wpOk  youtube#video
# 2   youtube#searchResult  F4JgoM-7y0mhqDWAyC0oy9Qdov0  youtube#video
# 3   youtube#searchResult  TJpAShnJxNVNBwUKoXihNPBOx04  youtube#video
# 4   youtube#searchResult  nZg4blnM02sqM4tXMbKq4LRRDOY  youtube#video
# ..                   ...                          ...            ...
# 45  youtube#searchResult  go_dkm830hcfPYfkCnL7O5kwLDQ  youtube#video
# 46  youtube#searchResult  IOUueqE9G0Ct7yvIYALmoDvplFU  youtube#video
# 47  youtube#searchResult  ED-JngnxVwVguxvrIBpvP9MXQTQ  youtube#video
# 48  youtube#searchResult  jZV0KaYHpJjERh7fErGsrvRuBTo  youtube#video
# 49  youtube#searchResult  B51geHAT3Utza8lMCbMco9N5y9o  youtube#video
#
#      id.videoId   snippet.publishedAt         snippet.channelId  \
# 0   m6ts866JgYc  2017-04-28T10:30:14Z  UCAddONSeww-GBynzG-oA1ag
# ...

# %% [markdown]
# В таблице 550 строк, то есть **550 видео**.

# %%
table.drop_duplicates(subset = ['id.videoId'], inplace = True)
table
# Out:
#                     kind                         etag        id.kind  \
# 0   youtube#searchResult  YQQxbM9BGr5kJpaFY0G-aCBn11g  youtube#video
# 1   youtube#searchResult  j-VFa0NUt9kO0ZI0xTLn9x4wpOk  youtube#video
# 2   youtube#searchResult  F4JgoM-7y0mhqDWAyC0oy9Qdov0  youtube#video
# 3   youtube#searchResult  TJpAShnJxNVNBwUKoXihNPBOx04  youtube#video
# 4   youtube#searchResult  nZg4blnM02sqM4tXMbKq4LRRDOY  youtube#video
# ..                   ...                          ...            ...
# 45  youtube#searchResult  go_dkm830hcfPYfkCnL7O5kwLDQ  youtube#video
# 46  youtube#searchResult  IOUueqE9G0Ct7yvIYALmoDvplFU  youtube#video
# 47  youtube#searchResult  ED-JngnxVwVguxvrIBpvP9MXQTQ  youtube#video
# 48  youtube#searchResult  jZV0KaYHpJjERh7fErGsrvRuBTo  youtube#video
# 49  youtube#searchResult  B51geHAT3Utza8lMCbMco9N5y9o  youtube#video
#
#      id.videoId   snippet.publishedAt         snippet.channelId  \
# 0   m6ts866JgYc  2017-04-28T10:30:14Z  UCAddONSeww-GBynzG-oA1ag
# ...

# %% [markdown]
# После удаления дубликатов по столбцу id.videoId в нашей таблице осталось 439 строк, то есть **439 видео**.

# %% [markdown]
# **6. Для всех видео соберите статистику (количество промотров, лайков, комментариев), используйте метод `.videos()`. Добавьте эти данные в вашу таблицу.**

# %%
video_ids = []

for video in response_search['items']:
    video_ids.append(video['id']['videoId'])
    
video_ids
    
video_50_request = youtube.videos().list(
    part = ['snippet', 'contentDetails', 'id', 'statistics'],
    id = video_ids)

video_50_response = video_50_request.execute()


likesCount = {}

table_2 = pd.json_normalize(video_50_response["items"]);
table_2.columns
# Out:
# Index(['kind', 'etag', 'id', 'snippet.publishedAt', 'snippet.channelId',
#        'snippet.title', 'snippet.description',
#        'snippet.thumbnails.default.url', 'snippet.thumbnails.default.width',
#        'snippet.thumbnails.default.height', 'snippet.thumbnails.medium.url',
#        'snippet.thumbnails.medium.width', 'snippet.thumbnails.medium.height',
#        'snippet.thumbnails.high.url', 'snippet.thumbnails.high.width',
#        'snippet.thumbnails.high.height', 'snippet.thumbnails.standard.url',
#        'snippet.thumbnails.standard.width',
#        'snippet.thumbnails.standard.height', 'snippet.thumbnails.maxres.url',
#        'snippet.thumbnails.maxres.width', 'snippet.thumbnails.maxres.height',
#        'snippet.channelTitle', 'snippet.categoryId',
#        'snippet.liveBroadcastContent', 'snippet.localized.title',
#        'snippet.localized.description', 'contentDetails.duration',
#        'contentDetails.dimension', 'contentDetails.definition',
# ...

# %%
table["statistics.viewCount"] = table_2["statistics.viewCount"]
table["statistics.likeCount"] = table_2["statistics.likeCount"]
table["statistics.commentCount"] = table_2["statistics.commentCount"]
table["snippet.categoryId"] = table_2["snippet.categoryId"]
table["contentDetails.duration"] = table_2["contentDetails.duration"]

table
# Out:
#                     kind                         etag        id.kind  \
# 0   youtube#searchResult  YQQxbM9BGr5kJpaFY0G-aCBn11g  youtube#video
# 1   youtube#searchResult  j-VFa0NUt9kO0ZI0xTLn9x4wpOk  youtube#video
# 2   youtube#searchResult  F4JgoM-7y0mhqDWAyC0oy9Qdov0  youtube#video
# 3   youtube#searchResult  TJpAShnJxNVNBwUKoXihNPBOx04  youtube#video
# 4   youtube#searchResult  nZg4blnM02sqM4tXMbKq4LRRDOY  youtube#video
# ..                   ...                          ...            ...
# 45         youtube#video  VTcenN4nCxSbKFe85dR0Sj3akTI            NaN
# 46         youtube#video  -X5PLtFctIxd6SgjjjxqkVNjyFI            NaN
# 47         youtube#video  y9mwnAtyauAxPHls3dkxRNwSeOg            NaN
# 48         youtube#video  DeWQMJbvaNsf7QrwB-zra0fcPpw            NaN
# 49         youtube#video  G5tqSkRzCFemBvL19hc0e1ApeQ4            NaN
#
#      id.videoId   snippet.publishedAt         snippet.channelId  \
# 0   m6ts866JgYc  2017-04-28T10:30:14Z  UCAddONSeww-GBynzG-oA1ag
# ...

# %% [markdown]
# **7. Обратите внимание на столбец `snippet.categoryId`, посмотрите на уникальные значения в нем.**
#
# *Это категория видео, нужно ее записать понятным нам языком.*
#
# **Здесь обратите внимание на метод `.videoCategories()`, примените его к каждой уникальной категории.**
#
# *Тут необязательно определять категорию каждого видео (ведь категории повторяются). Подумайте, как определить просто уникальные категории, которые есть, а потом уже их добавить к нужным видео.*
#
# **В итоге к вашей таблице добавится еще один столбец — название категории.**

# %%
table['snippet.categoryId'].describe()
# Out:
# count     200
# unique      6
# top        22
# freq       92
# Name: snippet.categoryId, dtype: object

# %%
table['snippet.categoryId'].unique()
# Out:
# array(['27', '22', '26', '24', '28', '29'], dtype=object)

# %% [markdown]
# **У нас 6 уникальных категорий.**

# %%
n_request = youtube.videoCategories().list(
    part = 'snippet',
    id = ['27', '22', '26', '24', '28', '29'])

n_response = n_request.execute()

table_3 = pd.json_normalize(n_response['items'])


j = 0
for row in table["snippet.categoryId"]:
    for i in n_response["items"]:
        if i["id"] != row:
            continue
        table.loc[j, "categoryTitle"] = i["snippet"]["title"]
        break
        j += 1

table
# Out:
#                     kind                         etag        id.kind  \
# 0   youtube#searchResult  YQQxbM9BGr5kJpaFY0G-aCBn11g  youtube#video
# 1   youtube#searchResult  j-VFa0NUt9kO0ZI0xTLn9x4wpOk  youtube#video
# 2   youtube#searchResult  F4JgoM-7y0mhqDWAyC0oy9Qdov0  youtube#video
# 3   youtube#searchResult  TJpAShnJxNVNBwUKoXihNPBOx04  youtube#video
# 4   youtube#searchResult  nZg4blnM02sqM4tXMbKq4LRRDOY  youtube#video
# ..                   ...                          ...            ...
# 45         youtube#video  VTcenN4nCxSbKFe85dR0Sj3akTI            NaN
# 46         youtube#video  -X5PLtFctIxd6SgjjjxqkVNjyFI            NaN
# 47         youtube#video  y9mwnAtyauAxPHls3dkxRNwSeOg            NaN
# 48         youtube#video  DeWQMJbvaNsf7QrwB-zra0fcPpw            NaN
# 49         youtube#video  G5tqSkRzCFemBvL19hc0e1ApeQ4            NaN
#
#      id.videoId   snippet.publishedAt         snippet.channelId  \
# 0   m6ts866JgYc  2017-04-28T10:30:14Z  UCAddONSeww-GBynzG-oA1ag
# ...

# %% [markdown]
# **8. Уберите из таблицы ненужные, по вашему мнению, столбцы. Обоснуйте свое решение.**

# %% [markdown]
# * Удалим **etag**, так как далее он нам не понадобится.
# * Удалим столбцы **kind** и **id.kind**,так как мы знаем, что рассматриваем видео из YouTube, эта информация избыточна.
# * Удалим **id**, **id.videoId**, **snippet.channelId**, так как имея snippet.title	и snippet.publishedAt (то есть точное название видео и точную дату его публикации) мы можем найти нужное нам видео при помощи поисковой сторки в YouToube и посмотреть канал, на котором оно опубликовано.
# * Удалим "технические" показатели видео: показатели ширины и высоты изображения и др. (начиная с **snippet.thumbnails.default.width** и до * **snippet.thumbnails.high.width**) как не представляющие интереса для анализа.
# * Удалим **snippet.tags**, так как вывод об информации, содержащейся в видео можно сделать по snippet.title и по snippet.description.
# * Удалим **snippet.defaultAudioLanguage**, так как запрос сделан на русском языке и можно предположить, что язык видео тоже будет русский.
# * Удалим **snippet.categoryId**, так как мы заменили этот столбец на categoryTitle.

# %%
# ваш код
table_3 = table.drop(columns = ['kind','etag', 'id.kind', 'id.videoId', 'id','snippet.channelId',
       'snippet.thumbnails.default.url', 'snippet.thumbnails.default.width',
       'snippet.thumbnails.default.height', 'snippet.thumbnails.medium.url',
       'snippet.thumbnails.medium.width', 'snippet.thumbnails.medium.height',
       'snippet.thumbnails.high.width', 'snippet.thumbnails.high.url',
       'snippet.thumbnails.high.height', 'snippet.thumbnails.standard.url',
       'snippet.thumbnails.standard.width','snippet.thumbnails.standard.height', 
        'snippet.thumbnails.maxres.url','snippet.thumbnails.maxres.width', 
        'snippet.thumbnails.maxres.height', 'snippet.channelTitle', 
        'snippet.categoryId', 'snippet.localized.description',
       'snippet.liveBroadcastContent', 'snippet.localized.title',
        'contentDetails.duration', 'snippet.publishTime',
       'contentDetails.dimension', 'contentDetails.definition',
       'contentDetails.caption', 'contentDetails.licensedContent',
       'contentDetails.projection', 'snippet.tags',
       'snippet.defaultAudioLanguage'])
table_3
# Out:
#      snippet.publishedAt                                      snippet.title  \
# 0   2017-04-28T10:30:14Z  Отрывок 3 из 5-го этапа обучения &quot;Рабочий...
# 1   2022-09-20T16:48:32Z       Проект загородного дома «Северная жемчужина»
# 2   2023-03-12T07:00:08Z  Частное домовладение! Обзор готового дома | Пр...
# 3   2016-01-04T21:59:15Z              #1 Проекты загородных домов 2015_БОНА
# 4   2018-01-24T10:43:46Z            Проект загородного дома площадью 318 м2
# ..                   ...                                                ...
# 45  2022-06-30T07:34:02Z           Проект загородного дома. Видный 229,8 м2
# 46  2016-03-29T09:00:37Z                            проект загородного дома
# 47  2022-11-24T07:59:48Z  Проект загородного дома с мансардой. СК Домово...
# 48  2020-08-07T15:20:22Z  Дипломная работа: Дизайн-проект загородного до...
# 49  2022-05-16T18:30:21Z             Индивидуальный проект загородного дома
#
# ...

# %% [markdown]
# **9. Переименуйте оставшиеся столбцы.**

# %%
# ваш код
table_4 = table_3
table_4.columns = ['Дата и время публикации', 'Заголовок', 'Описание','Количество просмотров', 'Количество лайков', 
                   'Количество сохранений','Количество комментариев', 'Категория']

table_4
# Out:
#    Дата и время публикации                                          Заголовок  \
# 0     2017-04-28T10:30:14Z  Отрывок 3 из 5-го этапа обучения &quot;Рабочий...
# 1     2022-09-20T16:48:32Z       Проект загородного дома «Северная жемчужина»
# 2     2023-03-12T07:00:08Z  Частное домовладение! Обзор готового дома | Пр...
# 3     2016-01-04T21:59:15Z              #1 Проекты загородных домов 2015_БОНА
# 4     2018-01-24T10:43:46Z            Проект загородного дома площадью 318 м2
# ..                     ...                                                ...
# 45    2022-06-30T07:34:02Z           Проект загородного дома. Видный 229,8 м2
# 46    2016-03-29T09:00:37Z                            проект загородного дома
# 47    2022-11-24T07:59:48Z  Проект загородного дома с мансардой. СК Домово...
# 48    2020-08-07T15:20:22Z  Дипломная работа: Дизайн-проект загородного до...
# 49    2022-05-16T18:30:21Z             Индивидуальный проект загородного дома
#
# ...

# %% [markdown]
# **10. Сохраните получившуюуся табличку в формате .csv.**

# %%
table_4.to_csv(r'C:\Users\SSkobeleva\Desktop\Новая папка\питон\бонус\my_data.csv', index = False)
